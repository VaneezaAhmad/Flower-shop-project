# %%
import pandas as pd
from helperfunc import *
import os
import json

# %%
with open('/Users/vaneezaahmad/Documents/Flatiron/Phase1/ds-east-042621-lectures/Phase_1/ds-apis-nbz32-main/.secrets/creds.json') as f:
    creds = json.load(f)
    key = creds["key"]

# %%
# create a variable  to keep track of which result you are in. 
# if os.path.exists(business_ss):
#     os.remove(business_ss)

business_ss="/Users/vaneezaahmad/Documents/Flatiron/Phase1/Project_Phase1/Flower-shop-project/silverspring-floral.csv"
business_lb = "/Users/vaneezaahmad/Documents/Flatiron/Phase1/Project_Phase1/Flower-shop-project/leesburg-floral.csv"

cur = 0
url_params = {
        'term': "Floral Shop",
        'location': 'Silver Spring+MD',
        'limit': 50,
        'offset': 0,
        "radius": 8047
    }

url_params2 = {
    'term': "Floral Shop",
    'location': 'Leesburg+VA',
    'limit': 50,
    'offset': 0,
    "radius": 8047
}
num=url_params['limit']

#set up a while loop to go through and grab the result 
while cur < num and cur < 1000:
    print(num)
    
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    print(cur)
    
    #make your API call with the new offset number
    results = api_call(url_params, key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    num+=len(parsed_results)
    # use your function to insert your parsed results into the db
    df_safe(business_ss, parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50

#
# Out:
# 50
# 200
# 100
# 200
# 150
# 200
# 200
# 200
# 250
# 200
# 300
# 200
# 350
# 200
# 400
# 200
# 450
# 200
# 500
# 200
# 550
# 200
# 600
# 200
# 650
# 200
# 700
# 200
# 750
# 200
# 800
# 200
# 850
# 200
# 900
# 200
# 950
# 200
# 1000
# 200
# 1050
# 200
# 1100
# 200
# 1150
# 200
# 1200
# 200
# 1248
# 200
# 1286
# 200
# 1314
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-1afed307c99b> in <module>
#       9     url_params['offset'] = cur
#      10     #make your API call with the new offset number
# ---> 11     results = api_call(url_params, "wCijZHsjx17hUqDfDmwlutHELx3aPqbe8V2c8o8mJbQ6mOBC41ucvAUJG4BuJQZS_knhj8XfIXpVipJxCBRlwu4EZDj-9TTGLwJFR_GArZO8J92YrCvq4QsnHESUYHYx" )
#      12
#      13     #after you get your results you can now use your function to parse those results
#
# ...

# %%
# if os.path.exists(business_ss):
#     os.remove(business_ss)

reviews_lb= "/Users/vaneezaahmad/Documents/Flatiron/Phase1/Project_Phase1/Flower-shop-project/leesburg_floral.csv"    
reviews_ss= "/Users/vaneezaahmad/Documents/Flatiron/Phase1/Project_Phase1/Flower-shop-project/silverspring_reviews.csv"

business_ss = "/Users/vaneezaahmad/Documents/Flatiron/Phase1/Project_Phase1/Flower-shop-project/silverspring-floral.csv"
business_lb = "/Users/vaneezaahmad/Documents/Flatiron/Phase1/Project_Phase1/Flower-shop-project/leesburg-floral.csv"

cur = 0
url_params = {
    'limit': 50,
    'offset': 0,
}
num=url_params['limit']

#set up a while loop to go through and grab the result 
while cur < num and cur < 1000:
    print(num)
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    
    #business id for silver spring
    idee= get_ids(business_ss)
    
    for i in range(0, len(idee)):
        print("hello")
        results = review_call(idee[i], key)
    
    #after you get your results you can now use your function to parse those results
        parsed_results = parse_reviews(results, idee[i])
        num+=len(parsed_results)
    # use your function to insert your parsed results into the db
        df_safe(reviews_ss, parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50
